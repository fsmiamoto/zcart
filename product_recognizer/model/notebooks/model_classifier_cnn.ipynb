# %% [markdown]
# This Notebook was inspired by [Sasank Chilamkurthy's](https://chsasank.github.io) tutorial on how to train a convolutional neural network for image classification using transfer learning: [cs231n notes](https://cs231n.github.io/transfer-learning/).

# %%
# %matplotlib inline

# %%
# License: BSD
# Authored by Sasank Chilamkurthy, modified for our project's training purposes 
# by Joao Pedro Zanlorensi

from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from PIL import Image, ImageDraw
import math
import shutil
import json

cudnn.benchmark = True
plt.ion()   # interactive mode

# %% [markdown]
# ## Extract and Prepare the Data
#
# We will use torchvision and torch.utils.data packages for loading the
# data.

# %%
! wget https://zcart-product-recognizer-data.s3.sa-east-1.amazonaws.com/raw_image_data.zip
! unzip ./raw_image_data.zip
! rm ./raw_image_data.zip

# %%
RAW_DATA_PATH = './raw_image_data/'
LABELS = {
    'post_it': {'id': 0, 'pictures': {}, 'total_pictures': 0}, 
    'guarana_soda': {'id': 1, 'pictures': {}, 'total_pictures': 0},
    'coke_soda': {'id': 2, 'pictures': {}, 'total_pictures': 0},
    'card_deck': {'id': 3, 'pictures': {}, 'total_pictures': 0},
    'blue_pens': {'id': 4, 'pictures': {}, 'total_pictures': 0}
}
AMT_CLASSES = len(LABELS)

# %%
import json
bounding_boxes = json.load(open(RAW_DATA_PATH + 'bounding_boxes.labels'))
print(json.dumps(bounding_boxes, indent=2)[0:600])
# Out:
# {
#   "version": 1,
#   "type": "bounding-box-labels",
#   "boundingBoxes": {
#     "unknown.39n097ne.ingestion-645f8b4d4f-p2vmk.jpg": [
#       {
#         "label": "guarana_soda",
#         "x": 120,
#         "y": 265,
#         "width": 172,
#         "height": 207
#       },
#       {
#         "label": "coke_soda",
#         "x": 285,
#         "y": 120,
#         "width": 136,
#         "height": 247
#       },
#       {
#         "label": "post_it",
#         "x": 162,
#         "y": 149,
#         "width": 158,
#         "height": 128
#       },
#       {
#         "label": "card_deck",
#         "x": 0,
#         "y": 14,
#         "width": 1

# %%
total_images = len(bounding_boxes['boundingBoxes'])

# %%
# Flipping the bounding_boxes dictionary as so as we know in which file each label can be seen more easily
for image in bounding_boxes["boundingBoxes"]:
  for obj in bounding_boxes["boundingBoxes"][image]:
    LABELS[obj['label']]['pictures'][RAW_DATA_PATH + image] = \
        {
            'x': obj['x'], 
            'y': obj['y'], 
            'width': obj['width'], 
            'height': obj['height']
         }
    LABELS[obj['label']]['total_pictures'] += 1

# %%
print('Total pictures for each class:')
for label in LABELS:
  print(label + ', ' + str(LABELS[label]['total_pictures']))
# Out:
# Total pictures for each class:
# post_it, 273
# guarana_soda, 283
# coke_soda, 276
# card_deck, 306
# blue_pens, 293

# %%
# Create a folder structure for training
if not os.path.exists('data'):
    for split in ['train', 'val']:
      for label in LABELS:
        os.makedirs(f'data/{split}/{label}')

# %%
def split_dataset(class_name, image_names, train_size, val_size):
  for i, impage_path_and_name in enumerate(image_names):
        # Split into train, val and test
        if i <= train_size:
            split = 'train'
        else:
            split = 'val'
        
        source_image_path = impage_path_and_name
        target_image_folder = f'data/{split}/{class_name}'
        shutil.copy(source_image_path, target_image_folder)

# %%
train_pct = 70

for label in LABELS:
  split_dataset(
      class_name  = label, 
      image_names = list(LABELS[label]['pictures'].keys()),
      train_size  = math.ceil(LABELS[label]['total_pictures'] * train_pct/100),
      val_size    = LABELS[label]['total_pictures'] - math.ceil(LABELS[label]['total_pictures'] * train_pct/100)
  )

# %%
mean_imagenet = [0.485, 0.456, 0.406]
std_imagenet = [0.229, 0.224, 0.225]

# %% [markdown]
# **Note:** these Normalization parameters are the mean and standard deviation RGB values from the tensors built out of the images that are a part of [ImageNet](https://www.image-net.org/).
# A reference for calculating the mean and standard deviation values for custom datasets can be found [here](https://www.geeksforgeeks.org/how-to-normalize-images-in-pytorch/).
# We'll go straight with he ImageNet values, but if needed we can try out the custom values for fine tuning.

# %%
data_transforms = {
    'train': transforms.Compose([
        #transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean_imagenet,std_imagenet)
    ]),
    'val': transforms.Compose([
        #transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean_imagenet,std_imagenet)
    ]),
}

data_dir = 'data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Visualize a few images
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array(mean_imagenet)
    std = np.array(std_imagenet)
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ## Training the model
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ### Visualizing the model predictions
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'predicted: {class_names[preds[j]]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ## Finetuning the convnet
#
# Load a pretrained model and reset final fully connected layer.

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features

model_ft.fc = nn.Linear(num_ftrs, AMT_CLASSES)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %% [markdown]
# ### Train and evaluate
#
# It should take around 15-25 min on CPU. On GPU though, it takes less than a
# minute.

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=200)
# Out:
# Epoch 0/199
# ----------
# train Loss: 0.9023 Acc: 0.5935
# val Loss: 0.1195 Acc: 0.9547
#
# Epoch 1/199
# ----------
# train Loss: 0.8842 Acc: 0.5935
# val Loss: 0.1189 Acc: 0.9597
#
# Epoch 2/199
# ----------
# train Loss: 0.8902 Acc: 0.5846
# val Loss: 0.1193 Acc: 0.9572
#
# Epoch 3/199
# ----------
# train Loss: 0.8746 Acc: 0.6113
# val Loss: 0.1060 Acc: 0.9597
#
# Epoch 4/199
# ----------
# train Loss: 0.8611 Acc: 0.6162
# val Loss: 0.1046 Acc: 0.9673
#
# Epoch 5/199
# ----------
# train Loss: 0.9178 Acc: 0.5836
# val Loss: 0.1100 Acc: 0.9647
#
# Epoch 6/199
# ----------
# train Loss: 0.8810 Acc: 0.5994
# val Loss: 0.1196 Acc: 0.9622
#
# Epoch 7/199
# ----------
# train Loss: 0.8698 Acc: 0.6182
# val Loss: 0.1159 Acc: 0.9572
#
# Epoch 8/199
# ----------
# train Loss: 0.8764 Acc: 0.5865
# val Loss: 0.1142 Acc: 0.9622
#
# Epoch 9/199
# ----------
# train Loss: 0.8651 Acc: 0.6014
# val Loss: 0.1093 Acc: 0.9597
#
# Epoch 10/199
# ----------
# train Loss: 0.8840 Acc: 0.6073
# val Loss: 0.1294 Acc: 0.9647
#
# Epoch 11/199
# ----------
# train Loss: 0.8906 Acc: 0.5826
# val Loss: 0.1201 Acc: 0.9597
#
# Epoch 12/199
# ----------
# train Loss: 0.8735 Acc: 0.5945
# val Loss: 0.1074 Acc: 0.9647
#
# Epoch 13/199
# ----------
# train Loss: 0.8949 Acc: 0.6142
# val Loss: 0.1128 Acc: 0.9647
#
# Epoch 14/199
# ----------
# train Loss: 0.8827 Acc: 0.5974
# val Loss: 0.1207 Acc: 0.9622
#
# Epoch 15/199
# ----------
# train Loss: 0.8790 Acc: 0.6004
# val Loss: 0.1134 Acc: 0.9597
#
# Epoch 16/199
# ----------
# train Loss: 0.8492 Acc: 0.6133
# val Loss: 0.1072 Acc: 0.9673
#
# Epoch 17/199
# ----------
# train Loss: 0.8941 Acc: 0.6034
# val Loss: 0.1128 Acc: 0.9622
#
# Epoch 18/199
# ----------
# train Loss: 0.9011 Acc: 0.5628
# val Loss: 0.1199 Acc: 0.9622
#
# Epoch 19/199
# ----------
# train Loss: 0.9010 Acc: 0.5935
# val Loss: 0.1093 Acc: 0.9647
#
# Epoch 20/199
# ----------
# train Loss: 0.8812 Acc: 0.6004
# val Loss: 0.1184 Acc: 0.9597
#
# Epoch 21/199
# ----------
# train Loss: 0.8768 Acc: 0.6044
# val Loss: 0.1205 Acc: 0.9496
#
# Epoch 22/199
# ----------
# train Loss: 0.8791 Acc: 0.6044
# val Loss: 0.1213 Acc: 0.9597
#
# Epoch 23/199
# ----------
# train Loss: 0.8721 Acc: 0.6073
# val Loss: 0.1160 Acc: 0.9572
#
# Epoch 24/199
# ----------
# train Loss: 0.8750 Acc: 0.6063
# val Loss: 0.1128 Acc: 0.9572
#
# Epoch 25/199
# ----------
# train Loss: 0.8795 Acc: 0.5856
# val Loss: 0.1168 Acc: 0.9597
#
# Epoch 26/199
# ----------
# train Loss: 0.9220 Acc: 0.5727
# val Loss: 0.1213 Acc: 0.9622
#
# Epoch 27/199
# ----------
# train Loss: 0.8800 Acc: 0.5945
# val Loss: 0.1070 Acc: 0.9597
#
# Epoch 28/199
# ----------
# train Loss: 0.8669 Acc: 0.6083
# val Loss: 0.1238 Acc: 0.9622
#
# Epoch 29/199
# ----------
# train Loss: 0.8908 Acc: 0.5945
# val Loss: 0.1125 Acc: 0.9622
#
# Epoch 30/199
# ----------
# train Loss: 0.8899 Acc: 0.5865
# val Loss: 0.1036 Acc: 0.9647
#
# Epoch 31/199
# ----------
# train Loss: 0.8733 Acc: 0.6004
# val Loss: 0.1036 Acc: 0.9673
#
# Epoch 32/199
# ----------
# train Loss: 0.8762 Acc: 0.5955
# val Loss: 0.1172 Acc: 0.9597
#
# Epoch 33/199
# ----------
# train Loss: 0.9174 Acc: 0.5628
# val Loss: 0.1172 Acc: 0.9622
#
# Epoch 34/199
# ----------
# train Loss: 0.8792 Acc: 0.5945
# val Loss: 0.1376 Acc: 0.9547
#
# Epoch 35/199
# ----------
# train Loss: 0.8604 Acc: 0.6093
# val Loss: 0.1253 Acc: 0.9572
#
# Epoch 36/199
# ----------
# train Loss: 0.8820 Acc: 0.5974
# val Loss: 0.1138 Acc: 0.9673
#
# Epoch 37/199
# ----------
# train Loss: 0.9002 Acc: 0.5767
# val Loss: 0.1125 Acc: 0.9673
#
# Epoch 38/199
# ----------
# train Loss: 0.8799 Acc: 0.5856
# val Loss: 0.1262 Acc: 0.9647
#
# Epoch 39/199
# ----------
# train Loss: 0.8792 Acc: 0.5974
# val Loss: 0.1138 Acc: 0.9597
#
# Epoch 40/199
# ----------
# train Loss: 0.8604 Acc: 0.6152
# val Loss: 0.1210 Acc: 0.9597
#
# Epoch 41/199
# ----------
# train Loss: 0.9069 Acc: 0.5856
# val Loss: 0.1125 Acc: 0.9647
#
# Epoch 42/199
# ----------
# train Loss: 0.8837 Acc: 0.6053
# val Loss: 0.1124 Acc: 0.9597
#
# Epoch 43/199
# ----------
# val Loss: 0.1104 Acc: 0.9597
#
# Epoch 147/199
# ----------
# train Loss: 0.9100 Acc: 0.5915
# val Loss: 0.1234 Acc: 0.9622
#
# Epoch 148/199
# ----------
# train Loss: 0.8868 Acc: 0.5875
# val Loss: 0.1157 Acc: 0.9622
#
# Epoch 149/199
# ----------
# train Loss: 0.8661 Acc: 0.6034
# val Loss: 0.1183 Acc: 0.9622
#
# Epoch 150/199
# ----------
# train Loss: 0.8814 Acc: 0.5895
# val Loss: 0.1221 Acc: 0.9521
#
# Epoch 151/199
# ----------
# train Loss: 0.9255 Acc: 0.5806
# val Loss: 0.1350 Acc: 0.9597
#
# Epoch 152/199
# ----------
# train Loss: 0.8806 Acc: 0.5806
# val Loss: 0.1165 Acc: 0.9597
#
# Epoch 153/199
# ----------
# train Loss: 0.8751 Acc: 0.6083
# val Loss: 0.1201 Acc: 0.9547
#
# Epoch 154/199
# ----------
# train Loss: 0.9093 Acc: 0.5816
# val Loss: 0.1191 Acc: 0.9597
#
# Epoch 155/199
# ----------
# train Loss: 0.9033 Acc: 0.5945
# val Loss: 0.1091 Acc: 0.9597
#
# Epoch 156/199
# ----------
# train Loss: 0.8855 Acc: 0.6063
# val Loss: 0.1106 Acc: 0.9698
#
# Epoch 157/199
# ----------
# train Loss: 0.8987 Acc: 0.5905
# val Loss: 0.1174 Acc: 0.9521
#
# Epoch 158/199
# ----------
# train Loss: 0.9162 Acc: 0.5786
# val Loss: 0.1069 Acc: 0.9673
#
# Epoch 159/199
# ----------
# train Loss: 0.8763 Acc: 0.6014
# val Loss: 0.1131 Acc: 0.9521
#
# Epoch 160/199
# ----------
# train Loss: 0.9099 Acc: 0.5865
# val Loss: 0.1247 Acc: 0.9496
#
# Epoch 161/199
# ----------
# train Loss: 0.9120 Acc: 0.5875
# val Loss: 0.1069 Acc: 0.9647
#
# Epoch 162/199
# ----------
# train Loss: 0.8794 Acc: 0.6034
# val Loss: 0.1217 Acc: 0.9597
#
# Epoch 163/199
# ----------
# val Loss: 0.1229 Acc: 0.9521
#
# Epoch 164/199
# ----------
# train Loss: 0.8898 Acc: 0.5826
# val Loss: 0.1070 Acc: 0.9622
#
# Epoch 165/199
# ----------
# train Loss: 0.8858 Acc: 0.6103
# val Loss: 0.1113 Acc: 0.9647
#
# Epoch 166/199
# ----------
# train Loss: 0.8812 Acc: 0.6034
# val Loss: 0.1140 Acc: 0.9597
#
# Epoch 167/199
# ----------
# train Loss: 0.9102 Acc: 0.5816
# val Loss: 0.1137 Acc: 0.9597
#
# Epoch 168/199
# ----------
# train Loss: 0.8772 Acc: 0.5915
# val Loss: 0.1171 Acc: 0.9572
#
# Epoch 169/199
# ----------
# train Loss: 0.8892 Acc: 0.5945
# val Loss: 0.1219 Acc: 0.9572
#
# Epoch 170/199
# ----------
# train Loss: 0.9102 Acc: 0.5846
# val Loss: 0.1220 Acc: 0.9572
#
# Epoch 171/199
# ----------
# train Loss: 0.9158 Acc: 0.5707
# val Loss: 0.1172 Acc: 0.9521
#
# Epoch 172/199
# ----------
# train Loss: 0.8818 Acc: 0.5935
# val Loss: 0.1292 Acc: 0.9572
#
# Epoch 199/199
# ----------
# train Loss: 0.8821 Acc: 0.6172
# val Loss: 0.1106 Acc: 0.9597
#
# Training complete in 25m 8s
# Best val Acc: 0.969773

# %%
visualize_model(model_ft)

# %%
model_scripted = torch.jit.script(model_ft) # Export to TorchScript
model_scripted.save('model_ft_scripted.pt') # Save

# %% [markdown]
# ## ConvNet as fixed feature extractor
#
# Here, we need to freeze all the network except the final layer. We need
# to set ``requires_grad = False`` to freeze the parameters so that the
# gradients are not computed in ``backward()``.
#
# You can read more about this in the documentation
# [here](https://pytorch.org/docs/notes/autograd.html#excluding-subgraphs-from-backward)_.

# %%
model_conv = torchvision.models.resnet18(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, AMT_CLASSES)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ### Train and evaluate
#
# On CPU this will take about half the time compared to previous scenario.
# This is expected as gradients don't need to be computed for most of the
# network. However, forward does need to be computed.

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=200)
# Out:
# Epoch 0/199
# ----------
# train Loss: 1.6838 Acc: 0.2750
# val Loss: 0.9615 Acc: 0.6373
#
# Epoch 1/199
# ----------
# train Loss: 1.4508 Acc: 0.3828
# val Loss: 1.5230 Acc: 0.6071
#
# Epoch 2/199
# ----------
# train Loss: 1.4264 Acc: 0.4352
# val Loss: 0.4770 Acc: 0.8413
#
# Epoch 3/199
# ----------
# train Loss: 1.3521 Acc: 0.4679
# val Loss: 0.4877 Acc: 0.8287
#
# Epoch 4/199
# ----------
# train Loss: 1.3800 Acc: 0.4560
# val Loss: 0.6501 Acc: 0.7708
#
# Epoch 5/199
# ----------
# train Loss: 1.2038 Acc: 0.5074
# val Loss: 0.5005 Acc: 0.8413
#
# Epoch 6/199
# ----------
# train Loss: 1.2742 Acc: 0.4876
# val Loss: 0.6364 Acc: 0.7884
#
# Epoch 7/199
# ----------
# train Loss: 1.1407 Acc: 0.5341
# val Loss: 0.4289 Acc: 0.8615
#
# Epoch 8/199
# ----------
# train Loss: 1.0938 Acc: 0.5361
# val Loss: 0.3507 Acc: 0.8841
#
# Epoch 9/199
# ----------
# train Loss: 1.0834 Acc: 0.5757
# val Loss: 0.3351 Acc: 0.8866
#
# Epoch 10/199
# ----------
# train Loss: 1.1112 Acc: 0.5440
# val Loss: 0.3675 Acc: 0.8741
#
# Epoch 11/199
# ----------
# train Loss: 1.0723 Acc: 0.5420
# val Loss: 0.3845 Acc: 0.8741
#
# Epoch 12/199
# ----------
# train Loss: 1.0964 Acc: 0.5697
# val Loss: 0.3464 Acc: 0.8766
#
# Epoch 13/199
# ----------
# train Loss: 1.0794 Acc: 0.5707
# val Loss: 0.3897 Acc: 0.8690
#
# Epoch 14/199
# ----------
# train Loss: 1.0441 Acc: 0.5638
# val Loss: 0.3719 Acc: 0.8690
#
# Epoch 15/199
# ----------
# train Loss: 1.0959 Acc: 0.5381
# val Loss: 0.3826 Acc: 0.8715
#
# Epoch 16/199
# ----------
# train Loss: 1.0651 Acc: 0.5509
# val Loss: 0.3659 Acc: 0.8791
#
# Epoch 17/199
# ----------
# train Loss: 1.0515 Acc: 0.5638
# val Loss: 0.3251 Acc: 0.8766
#
# Epoch 18/199
# ----------
# train Loss: 1.0821 Acc: 0.5569
# val Loss: 0.3336 Acc: 0.8892
#
# Epoch 19/199
# ----------
# train Loss: 1.0811 Acc: 0.5678
# val Loss: 0.3597 Acc: 0.8690
#
# Epoch 20/199
# ----------
# train Loss: 1.0637 Acc: 0.5697
# val Loss: 0.3380 Acc: 0.8841
#
# Epoch 21/199
# ----------
# train Loss: 1.0473 Acc: 0.5786
# val Loss: 0.3604 Acc: 0.8741
#
# Epoch 22/199
# ----------
# train Loss: 1.0571 Acc: 0.5559
# val Loss: 0.3431 Acc: 0.8791
#
# Epoch 23/199
# ----------
# train Loss: 1.0776 Acc: 0.5579
# val Loss: 0.3501 Acc: 0.8791
#
# Epoch 24/199
# ----------
# train Loss: 1.0570 Acc: 0.5796
# val Loss: 0.3543 Acc: 0.8816
#
# Epoch 25/199
# ----------
# train Loss: 1.0498 Acc: 0.5579
# val Loss: 0.3266 Acc: 0.8917
#
# Epoch 26/199
# ----------
# train Loss: 1.0903 Acc: 0.5490
# val Loss: 0.3585 Acc: 0.8866
#
# Epoch 27/199
# ----------
# train Loss: 1.0517 Acc: 0.5658
# val Loss: 0.3752 Acc: 0.8715
#
# Epoch 28/199
# ----------
# train Loss: 1.0949 Acc: 0.5539
# val Loss: 0.3347 Acc: 0.8766
#
# Epoch 29/199
# ----------
# train Loss: 1.0256 Acc: 0.5816
# val Loss: 0.3535 Acc: 0.8766
#
# Epoch 30/199
# ----------
# train Loss: 1.0882 Acc: 0.5519
# val Loss: 0.3645 Acc: 0.8791
#
# Epoch 31/199
# ----------
# train Loss: 1.0833 Acc: 0.5490
# val Loss: 0.3545 Acc: 0.8791
#
# Epoch 32/199
# ----------
# train Loss: 1.0733 Acc: 0.5589
# val Loss: 0.3637 Acc: 0.8715
#
# Epoch 33/199
# ----------
# train Loss: 1.0711 Acc: 0.5579
# val Loss: 0.3880 Acc: 0.8741
#
# Epoch 34/199
# ----------
# train Loss: 1.0560 Acc: 0.5440
# val Loss: 0.3563 Acc: 0.8715
#
# Epoch 35/199
# ----------
# train Loss: 1.0537 Acc: 0.5579
# val Loss: 0.3491 Acc: 0.8741
#
# Epoch 36/199
# ----------
# train Loss: 1.0537 Acc: 0.5717
# val Loss: 0.3514 Acc: 0.8791
#
# Epoch 37/199
# ----------
# train Loss: 1.0841 Acc: 0.5539
# val Loss: 0.3385 Acc: 0.8892
#
# Epoch 38/199
# ----------
# train Loss: 1.0504 Acc: 0.5569
# val Loss: 0.3643 Acc: 0.8715
#
# Epoch 39/199
# ----------
# train Loss: 1.1070 Acc: 0.5341
# val Loss: 0.3600 Acc: 0.8741
#
# Epoch 40/199
# ----------
# train Loss: 1.0848 Acc: 0.5579
# val Loss: 0.3781 Acc: 0.8741
#
# Epoch 41/199
# ----------
# train Loss: 1.0527 Acc: 0.5589
# val Loss: 0.3481 Acc: 0.8741
#
# Epoch 42/199
# ----------
# train Loss: 1.0468 Acc: 0.5638
# val Loss: 0.3827 Acc: 0.8715
#
# Epoch 43/199
# ----------
# train Loss: 1.0764 Acc: 0.5697
# val Loss: 0.3478 Acc: 0.8866
#
# Epoch 44/199
# ----------
# train Loss: 1.0679 Acc: 0.5727
# val Loss: 0.3350 Acc: 0.8741
#
# Epoch 45/199
# ----------
# train Loss: 1.0729 Acc: 0.5687
# val Loss: 0.3651 Acc: 0.8741
#
# Epoch 46/199
# ----------
# train Loss: 1.0597 Acc: 0.5757
# val Loss: 0.3619 Acc: 0.8841
#
# Epoch 47/199
# ----------
# train Loss: 1.0709 Acc: 0.5529
# val Loss: 0.3558 Acc: 0.8791
#
# Epoch 48/199
# ----------
# train Loss: 1.0853 Acc: 0.5539
# val Loss: 0.3533 Acc: 0.8841
#
# Epoch 49/199
# ----------
# train Loss: 1.0437 Acc: 0.5806
# val Loss: 0.3466 Acc: 0.8841
#
# Epoch 50/199
# ----------
# train Loss: 1.0845 Acc: 0.5618
# val Loss: 0.3452 Acc: 0.8816
#
# Epoch 51/199
# ----------
# train Loss: 1.0550 Acc: 0.5727
# val Loss: 0.3627 Acc: 0.8791
#
# Epoch 52/199
# ----------
# train Loss: 1.0560 Acc: 0.5371
# val Loss: 0.3321 Acc: 0.8866
#
# Epoch 53/199
# ----------
# train Loss: 1.0343 Acc: 0.5737
# val Loss: 0.3552 Acc: 0.8715
#
# Epoch 54/199
# ----------
# train Loss: 1.0837 Acc: 0.5569
# val Loss: 0.3648 Acc: 0.8766
#
# Epoch 55/199
# ----------
# train Loss: 1.0569 Acc: 0.5549
# val Loss: 0.3295 Acc: 0.8892
#
# Epoch 56/199
# ----------
# train Loss: 1.0412 Acc: 0.5816
# val Loss: 0.3637 Acc: 0.8791
#
# Epoch 57/199
# ----------
# train Loss: 1.0911 Acc: 0.5450
# val Loss: 0.3575 Acc: 0.8816
#
# Epoch 58/199
# ----------
# train Loss: 1.0475 Acc: 0.5628
# val Loss: 0.3684 Acc: 0.8766
#
# Epoch 59/199
# ----------
# train Loss: 1.0794 Acc: 0.5638
# val Loss: 0.3377 Acc: 0.8917
#
# Epoch 60/199
# ----------
# train Loss: 1.0587 Acc: 0.5668
# val Loss: 0.3555 Acc: 0.8816
#
# Epoch 61/199
# ----------
# train Loss: 1.0776 Acc: 0.5717
# val Loss: 0.3437 Acc: 0.8866
#
# Epoch 62/199
# ----------
# train Loss: 1.0672 Acc: 0.5628
# val Loss: 0.3691 Acc: 0.8766
#
# Epoch 63/199
# ----------
# train Loss: 1.0844 Acc: 0.5539
# val Loss: 0.3346 Acc: 0.8866
#
# Epoch 64/199
# ----------
# train Loss: 1.1029 Acc: 0.5420
# val Loss: 0.3737 Acc: 0.8615
#
# Epoch 65/199
# ----------
# train Loss: 1.0671 Acc: 0.5618
# val Loss: 0.3641 Acc: 0.8715
#
# Epoch 66/199
# ----------
# train Loss: 1.0978 Acc: 0.5638
# val Loss: 0.3455 Acc: 0.8791
#
# Epoch 67/199
# ----------
# train Loss: 1.0545 Acc: 0.5737
# val Loss: 0.3696 Acc: 0.8741
#
# Epoch 68/199
# ----------
# train Loss: 1.0485 Acc: 0.5678
# val Loss: 0.3373 Acc: 0.8841
#
# Epoch 69/199
# ----------
# train Loss: 1.0851 Acc: 0.5579
# val Loss: 0.3295 Acc: 0.8967
#
# Epoch 70/199
# ----------
# train Loss: 1.0900 Acc: 0.5569
# val Loss: 0.3490 Acc: 0.8791
#
# Epoch 71/199
# ----------
# train Loss: 1.0482 Acc: 0.5678
# val Loss: 0.3587 Acc: 0.8841
#
# Epoch 72/199
# ----------
# train Loss: 1.0640 Acc: 0.5618
# val Loss: 0.3685 Acc: 0.8715
#
# Epoch 73/199
# ----------
# train Loss: 1.0471 Acc: 0.5658
# val Loss: 0.3908 Acc: 0.8690
#
# Epoch 74/199
# ----------
# train Loss: 1.0695 Acc: 0.5648
# val Loss: 0.3529 Acc: 0.8741
#
# Epoch 75/199
# ----------
# train Loss: 1.0537 Acc: 0.5747
# val Loss: 0.3564 Acc: 0.8741
#
# Epoch 76/199
# ----------
# train Loss: 1.0518 Acc: 0.5727
# val Loss: 0.3652 Acc: 0.8715
#
# Epoch 77/199
# ----------
# train Loss: 1.0685 Acc: 0.5707
# val Loss: 0.3371 Acc: 0.8866
#
# Epoch 78/199
# ----------
# train Loss: 1.0440 Acc: 0.5806
# val Loss: 0.3464 Acc: 0.8866
#
# Epoch 79/199
# ----------
# train Loss: 1.0537 Acc: 0.5648
# val Loss: 0.3674 Acc: 0.8791
#
# Epoch 80/199
# ----------
# train Loss: 1.0880 Acc: 0.5579
# val Loss: 0.3795 Acc: 0.8766
#
# Epoch 81/199
# ----------
# train Loss: 1.0207 Acc: 0.5826
# val Loss: 0.3353 Acc: 0.8841
#
# Epoch 82/199
# ----------
# train Loss: 1.0720 Acc: 0.5509
# val Loss: 0.3349 Acc: 0.8892
#
# Epoch 83/199
# ----------
# train Loss: 1.0748 Acc: 0.5549
# val Loss: 0.3499 Acc: 0.8892
#
# Epoch 84/199
# ----------
# train Loss: 1.0867 Acc: 0.5529
# val Loss: 0.3870 Acc: 0.8665
#
# Epoch 85/199
# ----------
# train Loss: 1.0586 Acc: 0.5628
# val Loss: 0.3408 Acc: 0.8816
#
# Epoch 86/199
# ----------
# train Loss: 1.0503 Acc: 0.5856
# val Loss: 0.3132 Acc: 0.8942
#
# Epoch 87/199
# ----------
# train Loss: 1.0590 Acc: 0.5539
# val Loss: 0.3612 Acc: 0.8766
#
# Epoch 88/199
# ----------
# train Loss: 1.0678 Acc: 0.5549
# val Loss: 0.3321 Acc: 0.8892
#
# Epoch 89/199
# ----------
# train Loss: 1.0650 Acc: 0.5697
# val Loss: 0.3421 Acc: 0.8816
#
# Epoch 90/199
# ----------
# train Loss: 1.0630 Acc: 0.5707
# val Loss: 0.3421 Acc: 0.8766
#
# Epoch 91/199
# ----------
# train Loss: 1.0747 Acc: 0.5410
# val Loss: 0.3760 Acc: 0.8741
#
# Epoch 92/199
# ----------
# train Loss: 1.0478 Acc: 0.5569
# val Loss: 0.3324 Acc: 0.8892
#
# Epoch 93/199
# ----------
# train Loss: 1.0766 Acc: 0.5608
# val Loss: 0.3442 Acc: 0.8866
#
# Epoch 94/199
# ----------
# train Loss: 1.0765 Acc: 0.5628
# val Loss: 0.3752 Acc: 0.8791
#
# Epoch 95/199
# ----------
# train Loss: 1.0379 Acc: 0.5786
# val Loss: 0.3446 Acc: 0.8715
#
# Epoch 96/199
# ----------
# train Loss: 1.0456 Acc: 0.5628
# val Loss: 0.3291 Acc: 0.8917
#
# Epoch 97/199
# ----------
# train Loss: 1.0794 Acc: 0.5500
# val Loss: 0.3495 Acc: 0.8791
#
# Epoch 98/199
# ----------
# train Loss: 1.0818 Acc: 0.5559
# val Loss: 0.3777 Acc: 0.8741
#
# Epoch 99/199
# ----------
# train Loss: 1.0710 Acc: 0.5658
# val Loss: 0.3429 Acc: 0.8741
#
# Epoch 100/199
# ----------
# train Loss: 1.0837 Acc: 0.5480
# val Loss: 0.3533 Acc: 0.8841
#
# Epoch 101/199
# ----------
# train Loss: 1.0790 Acc: 0.5490
# val Loss: 0.3528 Acc: 0.8816
#
# Epoch 102/199
# ----------
# train Loss: 1.0553 Acc: 0.5618
# val Loss: 0.3156 Acc: 0.8866
#
# Epoch 103/199
# ----------
# train Loss: 1.0418 Acc: 0.5806
# val Loss: 0.3496 Acc: 0.8816
#
# Epoch 104/199
# ----------
# train Loss: 1.0768 Acc: 0.5539
# val Loss: 0.3644 Acc: 0.8766
#
# Epoch 105/199
# ----------
# train Loss: 1.0505 Acc: 0.5865
# val Loss: 0.3620 Acc: 0.8766
#
# Epoch 106/199
# ----------
# train Loss: 1.0716 Acc: 0.5430
# val Loss: 0.3443 Acc: 0.8766
#
# Epoch 107/199
# ----------
# train Loss: 1.0599 Acc: 0.5727
# val Loss: 0.3652 Acc: 0.8766
#
# Epoch 108/199
# ----------
# train Loss: 1.0566 Acc: 0.5687
# val Loss: 0.3576 Acc: 0.8715
#
# Epoch 109/199
# ----------
# train Loss: 1.0830 Acc: 0.5668
# val Loss: 0.3582 Acc: 0.8741
#
# Epoch 110/199
# ----------
# train Loss: 1.0664 Acc: 0.5618
# val Loss: 0.3664 Acc: 0.8816
#
# Epoch 111/199
# ----------
# train Loss: 1.0558 Acc: 0.5806
# val Loss: 0.3246 Acc: 0.8892
#
# Epoch 112/199
# ----------
# train Loss: 1.0599 Acc: 0.5678
# val Loss: 0.3831 Acc: 0.8715
#
# Epoch 113/199
# ----------
# train Loss: 1.0755 Acc: 0.5569
# val Loss: 0.3287 Acc: 0.8892
#
# Epoch 114/199
# ----------
# train Loss: 1.0624 Acc: 0.5658
# val Loss: 0.3771 Acc: 0.8741
#
# Epoch 115/199
# ----------
# train Loss: 1.0667 Acc: 0.5559
# val Loss: 0.3457 Acc: 0.8766
#
# Epoch 116/199
# ----------
# train Loss: 1.0537 Acc: 0.5737
# val Loss: 0.3414 Acc: 0.8892
#
# Epoch 117/199
# ----------
# train Loss: 1.0686 Acc: 0.5628
# val Loss: 0.3556 Acc: 0.8841
#
# Epoch 118/199
# ----------
# train Loss: 1.0672 Acc: 0.5500
# val Loss: 0.3373 Acc: 0.8892
#
# Epoch 119/199
# ----------
# train Loss: 1.0730 Acc: 0.5668
# val Loss: 0.3346 Acc: 0.8892
#
# Epoch 120/199
# ----------
# train Loss: 1.0877 Acc: 0.5638
# val Loss: 0.3225 Acc: 0.8892
#
# Epoch 121/199
# ----------
# train Loss: 1.0745 Acc: 0.5707
# val Loss: 0.3559 Acc: 0.8791
#
# Epoch 122/199
# ----------
# train Loss: 1.0552 Acc: 0.5697
# val Loss: 0.3685 Acc: 0.8766
#
# Epoch 123/199
# ----------
# train Loss: 1.0540 Acc: 0.5648
# val Loss: 0.3600 Acc: 0.8766
#
# Epoch 124/199
# ----------
# train Loss: 1.0658 Acc: 0.5608
# val Loss: 0.3365 Acc: 0.8942
#
# Epoch 125/199
# ----------
# train Loss: 1.0551 Acc: 0.5589
# val Loss: 0.3631 Acc: 0.8766
#
# Epoch 126/199
# ----------
# train Loss: 1.0363 Acc: 0.5796
# val Loss: 0.3623 Acc: 0.8741
#
# Epoch 127/199
# ----------
# train Loss: 1.0497 Acc: 0.5707
# val Loss: 0.3356 Acc: 0.8841
#
# Epoch 128/199
# ----------
# train Loss: 1.0520 Acc: 0.5628
# val Loss: 0.3512 Acc: 0.8741
#
# Epoch 129/199
# ----------
# train Loss: 1.0981 Acc: 0.5628
# val Loss: 0.3717 Acc: 0.8791
#
# Epoch 130/199
# ----------
# train Loss: 1.0415 Acc: 0.5608
# val Loss: 0.3626 Acc: 0.8791
#
# Epoch 131/199
# ----------
# train Loss: 1.0687 Acc: 0.5519
# val Loss: 0.3211 Acc: 0.8942
#
# Epoch 132/199
# ----------
# train Loss: 1.0700 Acc: 0.5598
# val Loss: 0.3113 Acc: 0.8917
#
# Epoch 133/199
# ----------
# train Loss: 1.1003 Acc: 0.5549
# val Loss: 0.3719 Acc: 0.8741
#
# Epoch 134/199
# ----------
# train Loss: 1.0683 Acc: 0.5608
# val Loss: 0.3788 Acc: 0.8690
#
# Epoch 135/199
# ----------
# train Loss: 1.0481 Acc: 0.5865
# val Loss: 0.3442 Acc: 0.8816
#
# Epoch 136/199
# ----------
# train Loss: 1.0700 Acc: 0.5509
# val Loss: 0.3634 Acc: 0.8741
#
# Epoch 137/199
# ----------
# train Loss: 1.0781 Acc: 0.5608
# val Loss: 0.3509 Acc: 0.8841
#
# Epoch 138/199
# ----------
# train Loss: 1.0611 Acc: 0.5569
# val Loss: 0.3369 Acc: 0.8917
#
# Epoch 139/199
# ----------
# train Loss: 1.0605 Acc: 0.5628
# val Loss: 0.3687 Acc: 0.8715
#
# Epoch 140/199
# ----------
# train Loss: 1.0633 Acc: 0.5638
# val Loss: 0.3509 Acc: 0.8766
#
# Epoch 141/199
# ----------
# train Loss: 1.0620 Acc: 0.5589
# val Loss: 0.3392 Acc: 0.8791
#
# Epoch 142/199
# ----------
# train Loss: 1.0638 Acc: 0.5608
# val Loss: 0.3919 Acc: 0.8640
#
# Epoch 143/199
# ----------
# train Loss: 1.0607 Acc: 0.5875
# val Loss: 0.3426 Acc: 0.8841
#
# Epoch 144/199
# ----------
# train Loss: 1.0941 Acc: 0.5351
# val Loss: 0.3256 Acc: 0.8917
#
# Epoch 145/199
# ----------
# train Loss: 1.0603 Acc: 0.5668
# val Loss: 0.3409 Acc: 0.8841
#
# Epoch 146/199
# ----------
# train Loss: 1.0565 Acc: 0.5658
# val Loss: 0.3517 Acc: 0.8866
#
# Epoch 147/199
# ----------
# train Loss: 1.0790 Acc: 0.5440
# val Loss: 0.3557 Acc: 0.8816
#
# Epoch 148/199
# ----------
# train Loss: 1.0341 Acc: 0.5776
# val Loss: 0.3370 Acc: 0.8841
#
# Epoch 149/199
# ----------
# train Loss: 1.0472 Acc: 0.5589
# val Loss: 0.3392 Acc: 0.8841
#
# Epoch 150/199
# ----------
# train Loss: 1.0386 Acc: 0.5549
# val Loss: 0.3360 Acc: 0.8816
#
# Epoch 151/199
# ----------
# train Loss: 1.0629 Acc: 0.5440
# val Loss: 0.3611 Acc: 0.8741
#
# Epoch 152/199
# ----------
# train Loss: 1.0587 Acc: 0.5678
# val Loss: 0.3252 Acc: 0.8892
#
# Epoch 153/199
# ----------
# train Loss: 1.0522 Acc: 0.5490
# val Loss: 0.3896 Acc: 0.8690
#
# Epoch 154/199
# ----------
# train Loss: 1.0637 Acc: 0.5727
# val Loss: 0.3727 Acc: 0.8741
#
# Epoch 155/199
# ----------
# train Loss: 1.0220 Acc: 0.5776
# val Loss: 0.3590 Acc: 0.8766
#
# Epoch 156/199
# ----------
# train Loss: 1.0293 Acc: 0.5786
# val Loss: 0.3295 Acc: 0.8841
#
# Epoch 157/199
# ----------
# train Loss: 1.0578 Acc: 0.5697
# val Loss: 0.3160 Acc: 0.8892
#
# Epoch 158/199
# ----------
# train Loss: 1.0725 Acc: 0.5717
# val Loss: 0.3582 Acc: 0.8715
#
# Epoch 159/199
# ----------
# train Loss: 1.0306 Acc: 0.5658
# val Loss: 0.3561 Acc: 0.8791
#
# Epoch 160/199
# ----------
# train Loss: 1.0664 Acc: 0.5767
# val Loss: 0.3705 Acc: 0.8791
#
# Epoch 161/199
# ----------
# train Loss: 1.0759 Acc: 0.5401
# val Loss: 0.3388 Acc: 0.8791
#
# Epoch 162/199
# ----------
# train Loss: 1.0653 Acc: 0.5539
# val Loss: 0.3391 Acc: 0.8841
#
# Epoch 163/199
# ----------
# train Loss: 1.0860 Acc: 0.5539
# val Loss: 0.3477 Acc: 0.8791
#
# Epoch 164/199
# ----------
# train Loss: 1.0685 Acc: 0.5351
# val Loss: 0.3271 Acc: 0.8866
#
# Epoch 165/199
# ----------
# train Loss: 1.0746 Acc: 0.5579
# val Loss: 0.3643 Acc: 0.8766
#
# Epoch 166/199
# ----------
# train Loss: 1.0872 Acc: 0.5589
# val Loss: 0.3797 Acc: 0.8690
#
# Epoch 167/199
# ----------
# train Loss: 1.0561 Acc: 0.5678
# val Loss: 0.3565 Acc: 0.8791
#
# Epoch 168/199
# ----------
# train Loss: 1.0489 Acc: 0.5697
# val Loss: 0.3736 Acc: 0.8791
#
# Epoch 169/199
# ----------
# train Loss: 1.0629 Acc: 0.5648
# val Loss: 0.3560 Acc: 0.8766
#
# Epoch 170/199
# ----------
# train Loss: 1.0599 Acc: 0.5707
# val Loss: 0.3652 Acc: 0.8715
#
# Epoch 171/199
# ----------
# train Loss: 1.0788 Acc: 0.5470
# val Loss: 0.3293 Acc: 0.8816
#
# Epoch 172/199
# ----------
# train Loss: 1.0862 Acc: 0.5598
# val Loss: 0.3679 Acc: 0.8715
#
# Epoch 173/199
# ----------
# train Loss: 1.0568 Acc: 0.5767
# val Loss: 0.3437 Acc: 0.8791
#
# Epoch 174/199
# ----------
# train Loss: 1.0601 Acc: 0.5687
# val Loss: 0.3236 Acc: 0.8892
#
# Epoch 175/199
# ----------
# train Loss: 1.0838 Acc: 0.5381
# val Loss: 0.3603 Acc: 0.8841
#
# Epoch 176/199
# ----------
# train Loss: 1.0303 Acc: 0.5925
# val Loss: 0.3653 Acc: 0.8816
#
# Epoch 177/199
# ----------
# train Loss: 1.0548 Acc: 0.5776
# val Loss: 0.3496 Acc: 0.8816
#
# Epoch 178/199
# ----------
# train Loss: 1.0801 Acc: 0.5519
# val Loss: 0.3356 Acc: 0.8866
#
# Epoch 179/199
# ----------
# train Loss: 1.0502 Acc: 0.5549
# val Loss: 0.3758 Acc: 0.8715
#
# Epoch 180/199
# ----------
# train Loss: 1.0718 Acc: 0.5678
# val Loss: 0.3240 Acc: 0.8917
#
# Epoch 181/199
# ----------
# train Loss: 1.0685 Acc: 0.5747
# val Loss: 0.3288 Acc: 0.8917
#
# Epoch 182/199
# ----------
# train Loss: 1.0324 Acc: 0.5727
# val Loss: 0.3422 Acc: 0.8791
#
# Epoch 183/199
# ----------
# train Loss: 1.0762 Acc: 0.5440
# val Loss: 0.3413 Acc: 0.8791
#
# Epoch 184/199
# ----------
# train Loss: 1.0536 Acc: 0.5628
# val Loss: 0.3750 Acc: 0.8791
#
# Epoch 185/199
# ----------
# train Loss: 1.0834 Acc: 0.5519
# val Loss: 0.3504 Acc: 0.8766
#
# Epoch 186/199
# ----------
# train Loss: 1.0881 Acc: 0.5598
# val Loss: 0.3709 Acc: 0.8791
#
# Epoch 187/199
# ----------
# train Loss: 1.0479 Acc: 0.5836
# val Loss: 0.3603 Acc: 0.8791
#
# Epoch 188/199
# ----------
# train Loss: 1.0686 Acc: 0.5608
# val Loss: 0.3358 Acc: 0.8791
#
# Epoch 189/199
# ----------
# train Loss: 1.0619 Acc: 0.5500
# val Loss: 0.3461 Acc: 0.8816
#
# Epoch 190/199
# ----------
# train Loss: 1.0762 Acc: 0.5460
# val Loss: 0.3550 Acc: 0.8791
#
# Epoch 191/199
# ----------
# train Loss: 1.0647 Acc: 0.5500
# val Loss: 0.3408 Acc: 0.8841
#
# Epoch 192/199
# ----------
# train Loss: 1.0553 Acc: 0.5776
# val Loss: 0.3700 Acc: 0.8715
#
# Epoch 193/199
# ----------
# train Loss: 1.0438 Acc: 0.5658
# val Loss: 0.3444 Acc: 0.8791
#
# Epoch 194/199
# ----------
# train Loss: 1.0630 Acc: 0.5638
# val Loss: 0.3455 Acc: 0.8816
#
# Epoch 195/199
# ----------
# train Loss: 1.0678 Acc: 0.5668
# val Loss: 0.3894 Acc: 0.8741
#
# Epoch 196/199
# ----------
# train Loss: 1.0812 Acc: 0.5648
# val Loss: 0.3316 Acc: 0.8841
#
# Epoch 197/199
# ----------
# train Loss: 1.0205 Acc: 0.6053
# val Loss: 0.3372 Acc: 0.8942
#
# Epoch 198/199
# ----------
# train Loss: 1.0559 Acc: 0.5658
# val Loss: 0.3373 Acc: 0.8841
#
# Epoch 199/199
# ----------
# train Loss: 1.0764 Acc: 0.5687
# val Loss: 0.3490 Acc: 0.8766
#
# Training complete in 16m 34s
# Best val Acc: 0.896725

# %%
visualize_model(model_conv)

plt.ioff()
plt.show()

# %%
model_scripted = torch.jit.script(model_conv) # Export to TorchScript
model_scripted.save('model_conv_scripted.pt') # Save

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! cp ./model_conv_scripted.pt ./drive/MyDrive/TCC
! cp ./model_ft_scripted.pt ./drive/MyDrive/TCC
